# %%
#import modules
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
data = pd.read_excel("Online Retail.xlsx")

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
data.size
# Out:
# 4335272

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
# InvoiceNo      541909 non-null object
# StockCode      541909 non-null object
# Description    540455 non-null object
# Quantity       541909 non-null int64
# InvoiceDate    541909 non-null datetime64[ns]
# UnitPrice      541909 non-null float64
# CustomerID     406829 non-null float64
# Country        541909 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
pd.notnull(data['CustomerID'])
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 541904    True
# 541905    True
# 541906    True
# 541907    True
# 541908    True
# Name: CustomerID, Length: 406829, dtype: bool

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
filtered_data = data[['Country','CustomerID']].drop_duplicates()

# %%
filtered_data.Country.value_counts()[:10].plot(kind='bar')

# %%
uk_data = data[data.Country=='United Kingdom']

# %%
uk_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
uk_data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  361878.000000  361878.000000  361878.000000
# mean       11.077029       3.256007   15547.871368
# std       263.129266      70.654731    1594.402590
# min    -80995.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   14194.000000
# 50%         4.000000       1.950000   15514.000000
# 75%        12.000000       3.750000   16931.000000
# max     80995.000000   38970.000000   18287.000000

# %%
uk_data = uk_data[uk_data.Quantity > 0]

# %%
uk_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354345 entries, 0 to 541893
# Data columns (total 8 columns):
# InvoiceNo      354345 non-null object
# StockCode      354345 non-null object
# Description    354345 non-null object
# Quantity       354345 non-null int64
# InvoiceDate    354345 non-null datetime64[ns]
# UnitPrice      354345 non-null float64
# CustomerID     354345 non-null float64
# Country        354345 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 24.3+ MB

# %%
uk_data = uk_data[['CustomerID','InvoiceDate','InvoiceNo','Quantity','UnitPrice']]

# %%
uk_data['TotalPrice']=uk_data['Quantity']*uk_data['UnitPrice']

# %%
uk_data['InvoiceDate'].min(),uk_data['InvoiceDate'].max()
# Out:
# (Timestamp('2010-12-01 08:26:00'), Timestamp('2011-12-09 12:49:00'))

# %%
uk_data['InvoiceDate']
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541889   2011-12-09 12:31:00
# 541890   2011-12-09 12:49:00
# 541891   2011-12-09 12:49:00
# 541892   2011-12-09 12:49:00
# 541893   2011-12-09 12:49:00
# Name: InvoiceDate, Length: 354345, dtype: datetime64[ns]

# %%
PRESENT = dt.datetime(2011,12,10)

# %%
uk_data['InvoiceDate']=pd.to_datetime(uk_data['InvoiceDate'])

# %%
PRESENT
# Out:
# datetime.datetime(2011, 12, 10, 0, 0)

# %%
rfm= uk_data.groupby('CustomerID').agg({'InvoiceDate': lambda date: (PRESENT - date.max()).days,
                                        'InvoiceNo': lambda num: len(num),
                                        'TotalPrice': lambda price: price.sum()})

# %%
rfm.columns
# Out:
# Index(['InvoiceDate', 'InvoiceNo', 'TotalPrice'], dtype='object')

# %%
rfm
# Out:
#             InvoiceDate  InvoiceNo  TotalPrice
# CustomerID
# 12346.0             325          1    77183.60
# 12747.0               2        103     4196.01
# 12748.0               0       4596    33719.73
# 12749.0               3        199     4090.88
# 12820.0               3         59      942.34
# ...                 ...        ...         ...
# 18280.0             277         10      180.60
# 18281.0             180          7       80.82
# 18282.0               7         12      178.05
# 18283.0               3        756     2094.88
# 18287.0              42         70     1837.28
#
# [3921 rows x 3 columns]

# %%
rfm_1 = uk_data.groupby('CustomerID').agg({'InvoiceDate': lambda date: (PRESENT - date.max()).days,
                                        'InvoiceNo': lambda num: len(num),
                                        'TotalPrice': lambda price: price.sum()})
# Out:
#   File "<ipython-input-41-15eb10a2d748>", line 2
#     'InvoiceNo': lambda num: len(num),
#                ^
# SyntaxError: invalid syntax

# %%
uk_data[uk_data.CustomerID == 12748]
# Out:
#         CustomerID         InvoiceDate InvoiceNo  Quantity  UnitPrice  \
# 1016       12748.0 2010-12-01 12:48:00    536521         1       4.95
# 3692       12748.0 2010-12-02 11:46:00    536641         1       4.25
# 8448       12748.0 2010-12-05 12:42:00    537136         1       2.95
# 8449       12748.0 2010-12-05 12:42:00    537136         1       2.55
# 8450       12748.0 2010-12-05 12:42:00    537136         1       1.25
# ...            ...                 ...       ...       ...        ...
# 541855     12748.0 2011-12-09 12:20:00    581580         1       6.75
# 541856     12748.0 2011-12-09 12:20:00    581580         1       2.95
# 541857     12748.0 2011-12-09 12:20:00    581580         1       1.45
# 541858     12748.0 2011-12-09 12:20:00    581580         2       5.75
# 541859     12748.0 2011-12-09 12:20:00    581580         1       4.95
#
#         TotalPrice
# 1016          4.95
# 3692          4.25
# 8448          2.95
# 8449          2.55
# 8450          1.25
# ...

# %%
rfm
# Out:
#             InvoiceDate  InvoiceNo  TotalPrice
# CustomerID
# 12346.0             325          1    77183.60
# 12747.0               2        103     4196.01
# 12748.0               0       4596    33719.73
# 12749.0               3        199     4090.88
# 12820.0               3         59      942.34
# ...                 ...        ...         ...
# 18280.0             277         10      180.60
# 18281.0             180          7       80.82
# 18282.0               7         12      178.05
# 18283.0               3        756     2094.88
# 18287.0              42         70     1837.28
#
# [3921 rows x 3 columns]

# %%
rfm.columns=['monetary','frequency','recency']

# %%
rfm['recency']= rfm['recency'].astype(int)

# %%
rfm.head()
# Out:
#             monetary  frequency  recency
# CustomerID
# 12346.0          325          1    77183
# 12747.0            2        103     4196
# 12748.0            0       4596    33719
# 12749.0            3        199     4090
# 12820.0            3         59      942

# %%
rfm.columns=['recency','frequency','monetary']

# %%
rfm
# Out:
#             recency  frequency  monetary
# CustomerID
# 12346.0         325          1     77183
# 12747.0           2        103      4196
# 12748.0           0       4596     33719
# 12749.0           3        199      4090
# 12820.0           3         59       942
# ...             ...        ...       ...
# 18280.0         277         10       180
# 18281.0         180          7        80
# 18282.0           7         12       178
# 18283.0           3        756      2094
# 18287.0          42         70      1837
#
# [3921 rows x 3 columns]

# %%
type(rfm.recency)
# Out:
# pandas.core.series.Series

# %%
rfm.sort_values(by='monetary',ascending=False)
# Out:
#             recency  frequency  monetary
# CustomerID
# 18102.0           0        431    259657
# 17450.0           8        337    194550
# 16446.0           0          3    168472
# 17511.0           2        963     91062
# 16029.0          38        242     81024
# ...             ...        ...       ...
# 17956.0         249          1        12
# 14792.0          63          2         6
# 16454.0          44          2         6
# 16738.0         297          1         3
# 13256.0          14          1         0
#
# [3921 rows x 3 columns]

# %%
rfm['r_quartile']=pd.qcut(rfm['recency'],4,['1','2','3','4'])
rfm['f_quartile']=pd.qcut(rfm['frequency'],4,['4','3','2','1'])
rfm['m_quartile']=pd.qcut(rfm['monetary'],4,['4','3','2','1'])

# %%
rfm
# Out:
#             recency  frequency  monetary r_quartile f_quartile m_quartile
# CustomerID
# 12346.0         325          1     77183          4          4          1
# 12747.0           2        103      4196          1          1          1
# 12748.0           0       4596     33719          1          1          1
# 12749.0           3        199      4090          1          1          1
# 12820.0           3         59       942          1          2          2
# ...             ...        ...       ...        ...        ...        ...
# 18280.0         277         10       180          4          4          4
# 18281.0         180          7        80          4          4          4
# 18282.0           7         12       178          1          4          4
# 18283.0           3        756      2094          1          1          1
# 18287.0          42         70      1837          2          2          1
#
# [3921 rows x 6 columns]

# %%
rfm['SCORE']=rfm['r_quartile'].astype(str)+rfm['f_quartile'].astype(str)+rfm['m_quartile'].astype(str)

# %%
rfm
# Out:
#             recency  frequency  monetary r_quartile f_quartile m_quartile  \
# CustomerID
# 12346.0         325          1     77183          4          4          1
# 12747.0           2        103      4196          1          1          1
# 12748.0           0       4596     33719          1          1          1
# 12749.0           3        199      4090          1          1          1
# 12820.0           3         59       942          1          2          2
# ...             ...        ...       ...        ...        ...        ...
# 18280.0         277         10       180          4          4          4
# 18281.0         180          7        80          4          4          4
# 18282.0           7         12       178          1          4          4
# 18283.0           3        756      2094          1          1          1
# 18287.0          42         70      1837          2          2          1
#
#            SCORE
# CustomerID
# 12346.0      441
# 12747.0      111
# ...

# %%
rfm.sort_values('SCORE',ascending=False)
# Out:
#             recency  frequency  monetary r_quartile f_quartile m_quartile  \
# CustomerID
# 16765.0         294          1        34          4          4          4
# 13161.0         313          8       112          4          4          4
# 17746.0         240          6       110          4          4          4
# 15607.0         336         13       104          4          4          4
# 17752.0         359          1        80          4          4          4
# ...             ...        ...       ...        ...        ...        ...
# 17419.0          11        206      4226          1          1          1
# 17422.0          16        117      1979          1          1          1
# 14503.0           3        164      3543          1          1          1
# 17426.0           8        271      5037          1          1          1
# 13883.0          10        142      2674          1          1          1
#
#            SCORE
# CustomerID
# 16765.0      444
# 13161.0      444
# ...

# %%
top_cust = rfm[rfm['SCORE']=='111']

# %%
top_cust
# Out:
#             recency  frequency  monetary r_quartile f_quartile m_quartile  \
# CustomerID
# 12747.0           2        103      4196          1          1          1
# 12748.0           0       4596     33719          1          1          1
# 12749.0           3        199      4090          1          1          1
# 12839.0           2        314      5591          1          1          1
# 12841.0           4        420      4022          1          1          1
# ...             ...        ...       ...        ...        ...        ...
# 18229.0          11        164      7276          1          1          1
# 18241.0           9        104      2073          1          1          1
# 18245.0           7        175      2567          1          1          1
# 18272.0           2        166      3078          1          1          1
# 18283.0           3        756      2094          1          1          1
#
#            SCORE
# CustomerID
# 12747.0      111
# 12748.0      111
# ...
