# %%
import pandas as pd

# %%
crimes = pd.read_csv('D:\python\Python_project\Datasets\Crime.csv')

# %%
crimes.head()
# Out:
#                              INSTANCEID INCIDENT_NO           DATE_REPORTED  \
# 0  FBCEF4B1-0E16-4D54-B8E7-61FA6656378C   149019911  08/12/2014 05:45:00 PM
# 1  74DC4E70-9BEC-40F2-9C82-7A4F07D52DCF   169021897  08/26/2016 04:57:00 AM
# 2  328B7DAF-7D67-4577-8531-4F342C04A725    21103676  08/23/2011 05:21:00 PM
# 3  80027D17-3F03-4AD9-8530-000D5E6E3A45   149019632  12/01/2012 08:00:00 AM
# 4  9EE3F254-E217-455A-B5B3-75F0A45473F6   189022696  08/18/2018 07:30:00 PM
#
#                 DATE_FROM                 DATE_TO  \
# 0  08/10/2014 05:45:00 PM  08/10/2014 06:00:00 PM
# 1  08/26/2016 04:40:00 AM  08/26/2016 04:50:00 AM
# 2  08/23/2011 04:25:00 PM  08/23/2011 04:40:00 PM
# 3  11/13/2009 12:00:00 PM  06/01/2012 12:00:00 PM
# 4  01/01/2015 12:00:00 AM  12/31/2017 12:00:00 AM
#
#                              CLSD    UCR               DST BEAT OFFENSE  ...  \
# 0                       J--CLOSED  201.0  CENTRAL BUSINESS    1    RAPE  ...
# 1                       J--CLOSED  201.0                 5    3    RAPE  ...
# 2                       J--CLOSED  600.0                 2    2   THEFT  ...
# 3  D--VICTIM REFUSED TO COOPERATE  201.0                 3    1    RAPE  ...
# 4                       J--CLOSED  201.0                 4    4    RAPE  ...
#
#   VICTIM_GENDER SUSPECT_AGE SUSPECT_RACE     SUSPECT_ETHNICITY SUSPECT_GENDER  \
# 0        FEMALE     UNKNOWN        WHITE  NOT OF HISPANIC ORIG           MALE
# 1        FEMALE     UNKNOWN        BLACK  NOT OF HISPANIC ORIG           MALE
# 2           NaN     UNKNOWN          NaN                   NaN            NaN
# 3        FEMALE       26-30        WHITE  NOT OF HISPANIC ORIG           MALE
# 4        FEMALE     UNKNOWN        BLACK  NOT OF HISPANIC ORIG           MALE
#
#   TOTALNUMBERVICTIMS TOTALSUSPECTS UCR_GROUP COMMUNITY_COUNCIL_NEIGHBORHOOD  \
# 0                1.0           1.0      RAPE           DOWNTOWN - PENDLETON
# 1                1.0           1.0      RAPE                   WINTON HILLS
# 2                1.0           NaN     THEFT                            NaN
# 3                1.0           1.0      RAPE                    SAYLER PARK
# 4                1.0           1.0      RAPE                  PADDOCK HILLS
#
#        ZIP
# 0  45202.0
# 1  45232.0
# 2  45208.0
# 3  45233.0
# 4  45229.0
#
# [5 rows x 40 columns]

# %%
crimes.columns
# Out:
# Index(['INSTANCEID', 'INCIDENT_NO', 'DATE_REPORTED', 'DATE_FROM', 'DATE_TO',
#        'CLSD', 'UCR', 'DST', 'BEAT', 'OFFENSE', 'LOCATION', 'THEFT_CODE',
#        'FLOOR', 'SIDE', 'OPENING', 'HATE_BIAS', 'DAYOFWEEK', 'RPT_AREA',
#        'CPD_NEIGHBORHOOD', 'SNA_NEIGHBORHOOD', 'WEAPONS', 'DATE_OF_CLEARANCE',
#        'HOUR_FROM', 'HOUR_TO', 'ADDRESS_X', 'LONGITUDE_X', 'LATITUDE_X',
#        'VICTIM_AGE', 'VICTIM_RACE', 'VICTIM_ETHNICITY', 'VICTIM_GENDER',
#        'SUSPECT_AGE', 'SUSPECT_RACE', 'SUSPECT_ETHNICITY', 'SUSPECT_GENDER',
#        'TOTALNUMBERVICTIMS', 'TOTALSUSPECTS', 'UCR_GROUP',
#        'COMMUNITY_COUNCIL_NEIGHBORHOOD', 'ZIP'],
#       dtype='object')

# %%
crimes=crimes.drop(['INSTANCEID','COMMUNITY_COUNCIL_NEIGHBORHOOD','FLOOR','SIDE','OPENING','CLSD', 'UCR', 'DST', 'BEAT','RPT_AREA','UCR_GROUP','THEFT_CODE','HATE_BIAS','VICTIM_ETHNICITY','SUSPECT_ETHNICITY'],axis=1)

# %%
crimes.dropna()
# Out:
#        INCIDENT_NO           DATE_REPORTED               DATE_FROM  \
# 13922    129036747  12/18/2012 10:30:00 PM  12/18/2012 10:24:00 PM
# 13929    149026722  10/20/2014 11:09:00 AM  10/19/2014 10:00:00 PM
# 13935    179011319  04/03/2017 08:50:00 PM  04/03/2017 05:00:00 PM
# 13937    139026892  09/29/2013 10:46:00 PM  09/29/2013 08:00:00 PM
# 13938    139014514  06/07/2013 08:33:00 PM  06/07/2013 08:20:00 PM
# ...            ...                     ...                     ...
# 394531   149028275  11/04/2014 06:10:00 PM  11/04/2014 05:40:00 PM
# 394533   189017619  06/30/2018 08:55:00 PM  06/30/2018 07:55:00 PM
# 394535    31110066  11/17/2011 08:51:00 PM  11/17/2011 08:40:00 PM
# 394536    11002934  07/11/2010 03:00:00 PM  07/09/2010 10:30:00 PM
# 394537   159026963  09/30/2015 02:18:00 PM  09/30/2015 01:00:00 PM
#
#                        DATE_TO                        OFFENSE  \
# 13922   12/18/2012 10:25:00 PM             AGGRAVATED ROBBERY
# 13929   10/20/2014 10:30:00 AM                          THEFT
# 13935   04/03/2017 05:10:00 PM             AGGRAVATED ROBBERY
# 13937   09/29/2013 09:00:00 PM           MENACING BY STALKING
# 13938   06/07/2013 08:30:00 PM                        ASSAULT
# ...                        ...                            ...
# 394531  11/04/2014 05:40:00 PM             AGGRAVATED ROBBERY
# 394533  06/30/2018 08:15:00 PM                        ASSAULT
# 394535  11/17/2011 08:48:00 PM  CRIMINAL DAMAGING/ENDANGERING
# 394536  07/09/2010 10:40:00 PM            AGGRAVATED MENACING
# 394537  09/30/2015 01:20:00 PM                        ASSAULT
#
#                        LOCATION  DAYOFWEEK CPD_NEIGHBORHOOD SNA_NEIGHBORHOOD  \
# 13922                 47-STREET    TUESDAY     WALNUT HILLS     WALNUT HILLS
# 13929            48-PARKING LOT     SUNDAY     WALNUT HILLS     WALNUT HILLS
# 13935            48-PARKING LOT     MONDAY       MOUNT AIRY         MT. AIRY
# 13937     01-SINGLE FAMILY HOME     SUNDAY    COLLEGE  HILL     COLLEGE HILL
# 13938                 47-STREET     FRIDAY         EVANSTON         EVANSTON
# ...                         ...        ...              ...              ...
# 394531                47-STREET    TUESDAY   OVER-THE-RHINE   OVER-THE-RHINE
# 394533              11-HOSPITAL   SATURDAY       CORRYVILLE       CORRYVILLE
# 394535                47-STREET   THURSDAY  WEST PRICE HILL  WEST PRICE HILL
# 394536          02-MULTI FAMILY     FRIDAY   OVER-THE-RHINE   OVER-THE-RHINE
# 394537  03-RESIDENTIAL FACILITY  WEDNESDAY     WALNUT HILLS     WALNUT HILLS
#
#                                                  WEAPONS  ... LATITUDE_X  \
# 13922                                       12 - HANDGUN  ...  39.126512
# 13929                                          99 - NONE  ...  39.129501
# 13935                                       12 - HANDGUN  ...  39.192750
# 13937   40 - PERSONAL WEAPONS (HANDS, FEET, TEETH, ETC.)  ...  39.207029
# 13938                                          99 - NONE  ...  39.140473
# ...                                                  ...  ...        ...
# 394531                                      12 - HANDGUN  ...  39.111243
# 394533  40 - PERSONAL WEAPONS (HANDS, FEET, TEETH, ETC.)  ...  39.136645
# 394535                     11--FIREARM (TYPE NOT STATED)  ...  39.115022
# 394536   40--PERSONAL WEAPONS (HANDS, FEET, TEETH, ETC.)  ...  39.112050
# 394537  40 - PERSONAL WEAPONS (HANDS, FEET, TEETH, ETC.)  ...  39.127156
#
#         VICTIM_AGE  VICTIM_RACE VICTIM_GENDER  SUSPECT_AGE  SUSPECT_RACE  \
# 13922        41-50        BLACK          MALE      UNKNOWN         BLACK
# 13929        31-40        BLACK        FEMALE        31-40         WHITE
# 13935     UNDER 18        BLACK          MALE     UNDER 18         BLACK
# 13937        31-40        BLACK          MALE        26-30         BLACK
# 13938        26-30        BLACK        FEMALE        18-25         BLACK
# ...            ...          ...           ...          ...           ...
# 394531       26-30        WHITE          MALE      UNKNOWN         BLACK
# 394533       51-60        WHITE        FEMALE        26-30         WHITE
# 394535       18-25        WHITE        FEMALE        18-25         BLACK
# 394536       31-40        BLACK          MALE      UNKNOWN         BLACK
# 394537       61-70        BLACK          MALE        41-50         BLACK
#
#        SUSPECT_GENDER TOTALNUMBERVICTIMS TOTALSUSPECTS      ZIP
# 13922            MALE                1.0           3.0  45206.0
# 13929            MALE                1.0           2.0  45206.0
# 13935            MALE                2.0           2.0  45239.0
# 13937          FEMALE                2.0           1.0  45224.0
# 13938          FEMALE                3.0           4.0  45207.0
# ...               ...                ...           ...      ...
# 394531           MALE                1.0           3.0  45202.0
# 394533           MALE                1.0           1.0  45229.0
# 394535           MALE                5.0           3.0  45205.0
# 394536           MALE                1.0           2.0  45202.0
# 394537           MALE                1.0           1.0  45206.0
#
# [147098 rows x 25 columns]
